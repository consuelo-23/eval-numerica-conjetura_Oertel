# %%
from get_cpoints import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
from new_oertel import new_oertel
import numpy as np

#From summary newrun8
vertices = np.asarray(
[[0.0,         0.69883305, 0.6204051 ],
 [0.0,         0.43796526, 0.7639187 ],
 [0.0,         0.26429846, 0.80327654],
 [0.0,         0.3896649,  0.63059311],
 [0.0,         0.10778621, 0.74295303],
 [1.0,         0.83848172, 0.55505375],
 [1.0,         0.82087398, 0.17909026],
 [1.0,         0.43854443, 0.23689527],
 [1.0,         0.09129925, 0.34429125],
 [1.0,         0.56021878, 0.55290044],
 [2.0,         0.62998455, 0.08189013],
 [2.0,         0.14523598, 0.19097131],
 [2.0,         0.86617142, 0.25269838],
 [2.0,         0.67948408, 0.17699176],
 [2.0,         0.79182945, 0.03898073]])
candidatos , ordenados = obtener_candidatos(vertices)
ordenados = np.vstack(ordenados)

bestCP, bestF, bestU = new_oertel(ordenados, candidatos)
# Out:
# Punto[0.         0.38602563 0.70512506] -> F: 0.07217282383581258
# Punto[1.         0.52079215 0.3851956 ] -> F: 0.36698287448456085
# Punto[2.         0.60107895 0.16088347] -> F: 0.1002694067647482
# Punto[1.         0.49355229 0.43300427] -> F: 0.36039513164410014
# Punto[1.         0.52024735 0.38615178] -> F: 0.37081091065575666
# Punto[1.         0.51971345 0.38708882] -> F: 0.37458053958423604
# Punto[1.         0.51917955 0.38802587] -> F: 0.3783681386249305
# Punto[1.         0.51864565 0.38896292] -> F: 0.38217370777784065
# Punto[1.         0.51811175 0.38989997] -> F: 0.38596772609544977
# Punto[1.         0.51757785 0.39083702] -> F: 0.3894445518464845
# Punto[1.         0.51704394 0.39177407] -> F: 0.3929380412637131
# Punto[1.         0.51651004 0.39271112] -> F: 0.39644819434713496
# Punto[1.         0.51597614 0.39364817] -> F: 0.3999750110967511
# Punto[1.         0.51544224 0.39458522] -> F: 0.403518491512561
# ...
