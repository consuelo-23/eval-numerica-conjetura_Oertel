# %%
from get_cpoints import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
from new_oertel import new_oertel
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from get_cpoints import ordenar_vertices

# %%
seed = np.random.seed(16469)

vertices = random_vertices_by_fiber([0,1,2], 2, 5)
print(vertices)
candidatos , ordenados = obtener_candidatos(vertices)
ordenados = np.vstack(ordenados)

bestCP, bestF, bestU, best_indice = new_oertel(ordenados, candidatos)


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], 
        c='blue', s=150, label='Puntos Input', alpha=0.5)
plt.show()
# Out:
# [[0.         0.42952983 0.81316496]
#  [0.         0.77527515 0.58997708]
#  [0.         0.2471078  0.90860791]
#  [0.         0.74904735 0.56991393]
#  [0.         0.55378691 0.74349415]
#  [1.         0.62866027 0.99010376]
#  [1.         0.87782631 0.11598061]
#  [1.         0.68068832 0.79589575]
#  [1.         0.4248034  0.51933697]
#  [1.         0.56123841 0.49555462]
#  [2.         0.22798754 0.03057636]
#  [2.         0.39783404 0.07617288]
#  [2.         0.34335381 0.95088272]
#  [2.         0.99682508 0.14467119]
#  [2.         0.52033157 0.9397101 ]]
# Punto[0.         0.56285422 0.71326846] -> F: 0.0088863708164521
# Punto[1.         0.56032246 0.57271735] -> F: 0.22955871373429151
# Punto[2.         0.53862094 0.42481895] -> F: 0.23595349569550225
# Punto[1.         0.55073758 0.5690437 ] -> F: 0.22351820010877033
# Punto[1.         0.56013076 0.57264388] -> F: 0.22963819536362845
# Punto[1.         0.5599429  0.57257187] -> F: 0.22971609858902953
# ...

# %%
#del menos f al 2.5 mayor
seeds = [16469,18137,1934,1271,1984,18559,17021,18600,6784,16350,11394,8973,3931,2716,2693,15777,8739,10997,5060,2909,1958,8347,5672,10819,15139,16480,8197,14514,14834,17042,16283,4358,8222,2164,16300,5650,15743,18744,12723,9787,15565,6595,15274,5786]

for i in seeds:
    seed = np.random.seed(i)
    vertices = random_vertices_by_fiber([0,1,2], 2, 5)
    print(vertices)


    x = vertices[:,0]
    y = vertices[:,1]
    z = vertices[:,2]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='blue', s=10, label='Puntos Input', alpha=0.5)
    #ax.plot(x, y, z, c='blue', alpha=0.7, label='Línea de Conexión')

    plt.show()
# Out:
# [[0.         0.42952983 0.81316496]
#  [0.         0.77527515 0.58997708]
#  [0.         0.2471078  0.90860791]
#  [0.         0.74904735 0.56991393]
#  [0.         0.55378691 0.74349415]
#  [1.         0.62866027 0.99010376]
#  [1.         0.87782631 0.11598061]
#  [1.         0.68068832 0.79589575]
#  [1.         0.4248034  0.51933697]
#  [1.         0.56123841 0.49555462]
#  [2.         0.22798754 0.03057636]
#  [2.         0.39783404 0.07617288]
#  [2.         0.34335381 0.95088272]
#  [2.         0.99682508 0.14467119]
#  [2.         0.52033157 0.9397101 ]]
# [[0.         0.77326925 0.57763015]
#  [0.         0.83760802 0.60035907]
#  [0.         0.30057401 0.60685448]
#  [0.         0.92410269 0.61052066]
#  [0.         0.51992927 0.58250509]
#  [1.         0.31372596 0.83855441]
#  [1.         0.18555182 0.53105619]
#  [1.         0.05860578 0.78491644]
#  [1.         0.28413968 0.91719556]
#  [1.         0.55168591 0.37940877]
#  [2.         0.37030061 0.85951065]
# ...
