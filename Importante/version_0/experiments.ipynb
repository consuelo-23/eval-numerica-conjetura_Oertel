# %%
from get_cpoints import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
from new_oertel import new_oertel
import numpy as np

vertices = random_vertices_by_fiber([0,1,2], 2, 5)
candidatos , ordenados = obtener_candidatos(vertices)
ordenados = np.vstack(ordenados)

bestCP, bestF, bestU = new_oertel(ordenados, candidatos)
# Out:
# Punto[0.         0.65933984 0.56890223] -> F: 0.0
# Punto[1.         0.56994602 0.55235757] -> F: 0.3778044434957273
# Punto[2.         0.52485884 0.55927415] -> F: 0.09089979272869053
# Punto[1.         0.59209934 0.56408819] -> F: 0.3598410418119896
# Punto[1.         0.57038909 0.55259218] -> F: 0.37785409744127557
# Punto[1.         0.57082329 0.5528221 ] -> F: 0.3775767828780451
# Punto[1.         0.5712575  0.55305202] -> F: 0.3772062117240133
# Punto[1.         0.5716917  0.55328194] -> F: 0.37683599962226155
# Punto[1.         0.57212591 0.55351186] -> F: 0.3764661465727903
# Punto[1.         0.57256011 0.55374178] -> F: 0.37609665257559904
# Punto[1.         0.57299432 0.5539717 ] -> F: 0.375727517630688
# Punto[1.         0.57342852 0.55420163] -> F: 0.3753587417380571
# Punto[1.         0.57386273 0.55443155] -> F: 0.37499032489770645
# Punto[1.         0.57429693 0.55466147] -> F: 0.374622267109636
# Punto[1.         0.57473114 0.55489139] -> F: 0.3742545683738456
# Punto[1.         0.57516534 0.55512131] -> F: 0.3738872286903355
# Punto[1.         0.57559955 0.55535123] -> F: 0.3735202480591058
# Punto[1.         0.57603375 0.55558115] -> F: 0.37315362648015576
# Punto[1.         0.57646796 0.55581107] -> F: 0.37278736395348633
# Punto[1.         0.57690216 0.55604099] -> F: 0.372421460479097
# Punto[1.         0.57733637 0.55627091] -> F: 0.3720559160569878
# Punto[1.         0.57777057 0.55650083] -> F: 0.37169073068715897
# Punto[1.         0.57820478 0.55673075] -> F: 0.3713259043696101
# Punto[1.         0.57863898 0.55696067] -> F: 0.3709614371043416
# Punto[1.         0.57907319 0.55719059] -> F: 0.3705973288913533
# Punto[1.         0.57950739 0.55742051] -> F: 0.3702335797306449
# Punto[1.         0.5799416  0.55765043] -> F: 0.3698701896222169
# Punto[1.         0.5803758  0.55788035] -> F: 0.3695071585660693
# Punto[1.         0.58081001 0.55811027] -> F: 0.3691444865622015
# Punto[1.         0.58124421 0.55834019] -> F: 0.3687821736106142
# Punto[1.         0.58167842 0.55857011] -> F: 0.3684202197113068
# Punto[1.         0.58211262 0.55880003] -> F: 0.3680586248642797
# Punto[1.         0.58254683 0.55902995] -> F: 0.3676973890695329
# Punto[1.         0.58298103 0.55925987] -> F: 0.36733651232706627
# Punto[1.         0.58341524 0.55948979] -> F: 0.3669759946368796
# Punto[1.         0.58384944 0.55971971] -> F: 0.3666158359989735
# Punto[1.         0.58428365 0.55994963] -> F: 0.3662560364133472
# Punto[1.         0.58471785 0.56017955] -> F: 0.36589659588000145
# Punto[1.         0.58515206 0.56040947] -> F: 0.36553751439893556
# Punto[1.         0.58558626 0.56063939] -> F: 0.36517879197015
# Punto[1.         0.58602047 0.56086931] -> F: 0.3648204285936447
# Punto[1.         0.58645468 0.56109923] -> F: 0.36446242426941955
# Punto[1.         0.58688888 0.56132915] -> F: 0.3641047789974745
# Punto[1.         0.58732309 0.56155907] -> F: 0.36374749277780977
# Punto[1.         0.58775729 0.56178899] -> F: 0.36339056561042515
# Punto[1.         0.5881915  0.56201891] -> F: 0.3630339974953207
# Punto[1.         0.5886257  0.56224883] -> F: 0.3626777884324966
# Punto[1.         0.58905991 0.56247875] -> F: 0.36232193842195254
# Punto[1.         0.58949411 0.56270867] -> F: 0.36196644746368867
# Punto[1.         0.58992832 0.56293859] -> F: 0.36161131555770504
# Punto[1.         0.59036252 0.56316851] -> F: 0.3612565427040016
# Punto[1.         0.59079673 0.56339843] -> F: 0.3609021289025782
# Punto[1.         0.59123093 0.56362835] -> F: 0.36054807415343526
# Punto[1.         0.59166514 0.56385827] -> F: 0.3601943784565723
# Best centerpoint:  [1.         0.57038909 0.55259218] Best F:  0.37785409744127557 Best u:  [ 0.61290705  0.24417133 -0.75148207] índice:  0.02
