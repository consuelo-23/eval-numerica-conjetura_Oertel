# %%
from get_cpoints import random_vertices_by_fiber
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.spatial import ConvexHull
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np
# Out:
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)
#
#
# Caching the list of root modules, please wait!
# (This will only be done once - type '%rehashx' to reset cache!)

# %%
#del menos f al 2.5 mayor
seeds = [16469,18137,1934,1271,1984,18559,17021,18600,6784,16350]
         #,11394,8973,3931,2716,2693,15777,8739,10997,5060,2909,1958,8347,5672,10819,15139,16480,8197,14514,14834,17042,16283,4358,8222,2164,16300,5650,15743,18744,12723,9787,15565,6595,15274,5786]

for i in seeds:
    seed = np.random.seed(i)
    vertices = random_vertices_by_fiber([0,1,2], 2, 5)

    hull = ConvexHull(vertices)

    print(vertices)

    x = vertices[:,0]
    y = vertices[:,1]
    z = vertices[:,2]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='blue', s=10, label='Puntos Input', alpha=0.5)
    #ax.plot(x, y, z, c='blue', alpha=0.7, label='Línea de Conexión')

    envoltura = Poly3DCollection(vertices[hull.simplices])
    envoltura.set_facecolor('cyan')
    envoltura.set_alpha(0.3)
    envoltura.set_edgecolor('blue')
    envoltura.set_linewidth(0.5)

    ax.add_collection3d(envoltura)

    plt.show()
# Out:
# [[0.         0.42952983 0.81316496]
#  [0.         0.77527515 0.58997708]
#  [0.         0.2471078  0.90860791]
#  [0.         0.74904735 0.56991393]
#  [0.         0.55378691 0.74349415]
#  [1.         0.62866027 0.99010376]
#  [1.         0.87782631 0.11598061]
#  [1.         0.68068832 0.79589575]
#  [1.         0.4248034  0.51933697]
#  [1.         0.56123841 0.49555462]
#  [2.         0.22798754 0.03057636]
#  [2.         0.39783404 0.07617288]
#  [2.         0.34335381 0.95088272]
#  [2.         0.99682508 0.14467119]
#  [2.         0.52033157 0.9397101 ]]
# [[0.         0.77326925 0.57763015]
#  [0.         0.83760802 0.60035907]
#  [0.         0.30057401 0.60685448]
#  [0.         0.92410269 0.61052066]
#  [0.         0.51992927 0.58250509]
#  [1.         0.31372596 0.83855441]
#  [1.         0.18555182 0.53105619]
#  [1.         0.05860578 0.78491644]
#  [1.         0.28413968 0.91719556]
#  [1.         0.55168591 0.37940877]
#  [2.         0.37030061 0.85951065]
#  [2.         0.0739258  0.28854666]
#  [2.         0.07606402 0.61318147]
#  [2.         0.94640472 0.57644544]
#  [2.         0.19374699 0.16049924]]
# [[0.00000000e+00 2.54652728e-01 1.73172756e-01]
#  [0.00000000e+00 3.67181938e-01 1.35967990e-01]
#  [0.00000000e+00 5.17839466e-01 1.49420740e-01]
#  [0.00000000e+00 1.14544999e-01 8.65744067e-02]
#  [0.00000000e+00 2.92229706e-01 1.77296481e-01]
#  [1.00000000e+00 6.60725416e-01 3.37410569e-01]
#  [1.00000000e+00 3.36161362e-01 4.29462348e-01]
#  [1.00000000e+00 9.14337363e-01 5.50332047e-01]
#  [1.00000000e+00 2.02878224e-01 4.96043820e-01]
#  [1.00000000e+00 2.36904947e-01 6.03387924e-01]
#  [2.00000000e+00 1.60604163e-03 5.32780932e-01]
#  [2.00000000e+00 5.45902453e-01 3.76936145e-01]
#  [2.00000000e+00 8.72519945e-01 8.95285642e-01]
#  [2.00000000e+00 8.78521818e-01 4.11789009e-01]
#  [2.00000000e+00 5.59924961e-02 4.17689600e-01]]
# [[0.         0.08482016 0.57718741]
#  [0.         0.9049527  0.90262225]
#  [0.         0.10091194 0.15005473]
#  [0.         0.68096257 0.93834487]
#  [0.         0.85563296 0.16323702]
#  [1.         0.35314192 0.89420428]
#  [1.         0.54136601 0.55366649]
#  [1.         0.9578166  0.7987959 ]
#  [1.         0.68891183 0.44837514]
#  [1.         0.31716992 0.84912247]
#  [2.         0.29690867 0.32088587]
#  [2.         0.36807854 0.08402662]
#  [2.         0.40545343 0.07391404]
#  [2.         0.1919406  0.55148922]
#  [2.         0.31876932 0.39103044]]
# [[0.         0.00875573 0.29874557]
#  [0.         0.05641407 0.48268692]
#  [0.         0.28184322 0.794274  ]
#  [0.         0.29180757 0.7347585 ]
#  [0.         0.22156677 0.7164294 ]
#  [1.         0.05173477 0.49551781]
#  [1.         0.6625002  0.74884771]
#  [1.         0.70220684 0.25435969]
#  [1.         0.54762501 0.72802443]
#  [1.         0.79250279 0.22616673]
#  [2.         0.04926547 0.11584708]
#  [2.         0.9951388  0.79756743]
#  [2.         0.57700001 0.18489245]
#  [2.         0.12829891 0.74101994]
#  [2.         0.26291438 0.6475314 ]]
# [[0.         0.02586125 0.52115023]
#  [0.         0.95896677 0.20084518]
#  [0.         0.68776187 0.92728843]
#  [0.         0.3673128  0.84997458]
#  [0.         0.12269898 0.31439832]
#  [1.         0.35294414 0.7561953 ]
#  [1.         0.40066524 0.24513609]
#  [1.         0.58221092 0.00241572]
#  [1.         0.80304896 0.57299164]
#  [1.         0.88214127 0.09327788]
#  [2.         0.36825938 0.37243118]
#  [2.         0.48750641 0.58121839]
#  [2.         0.4095723  0.34789037]
#  [2.         0.55538195 0.64993855]
#  [2.         0.59372064 0.80977813]]
# [[0.         0.58585809 0.62343154]
#  [0.         0.34965945 0.47745566]
#  [0.         0.81718172 0.77255311]
#  [0.         0.24436355 0.38744932]
#  [0.         0.68421916 0.69901165]
#  [1.         0.69881232 0.41007985]
#  [1.         0.32770875 0.03384754]
#  [1.         0.72620142 0.50805211]
#  [1.         0.92396585 0.43854411]
#  [1.         0.69157719 0.31024349]
#  [2.         0.56232263 0.06597465]
#  [2.         0.20111905 0.51636098]
#  [2.         0.37551645 0.67050732]
#  [2.         0.19922245 0.17858819]
#  [2.         0.98066578 0.54742396]]
# [[0.         0.95543975 0.4470709 ]
#  [0.         0.89494061 0.869291  ]
#  [0.         0.48543238 0.80347368]
#  [0.         0.10519524 0.79568904]
#  [0.         0.9379793  0.03416829]
#  [1.         0.72892749 0.1100535 ]
#  [1.         0.5444354  0.20566125]
#  [1.         0.51957894 0.35536247]
#  [1.         0.10990077 0.49715343]
#  [1.         0.70852423 0.24149979]
#  [2.         0.15136546 0.47757788]
#  [2.         0.68429402 0.16683398]
#  [2.         0.3166149  0.35651084]
#  [2.         0.54118897 0.30748   ]
#  [2.         0.4619165  0.24242057]]
# [[0.         0.02151438 0.57736926]
#  [0.         0.99713067 0.98341528]
#  [0.         0.95797162 0.06009384]
#  [0.         0.3633497  0.92566958]
#  [0.         0.82963888 0.86134648]
#  [1.         0.35500373 0.27203852]
#  [1.         0.10284408 0.87423524]
#  [1.         0.6030561  0.23752438]
#  [1.         0.06520852 0.32081546]
#  [1.         0.05581486 0.4495711 ]
#  [2.         0.52911538 0.1920056 ]
#  [2.         0.6473016  0.18829031]
#  [2.         0.49808732 0.15085068]
#  [2.         0.20422581 0.25542795]
#  [2.         0.6122392  0.03045917]]
# [[0.         0.38492541 0.98279983]
#  [0.         0.7525498  0.95698608]
#  [0.         0.48957568 0.06359224]
#  [0.         0.06607759 0.82856383]
#  [0.         0.85779503 0.57244201]
#  [1.         0.39219375 0.73278113]
#  [1.         0.19377543 0.53300436]
#  [1.         0.92765511 0.4465151 ]
#  [1.         0.50458381 0.89969619]
#  [1.         0.23199468 0.66863259]
#  [2.         0.25692004 0.53746384]
#  [2.         0.29475577 0.18260746]
#  [2.         0.24364159 0.5777635 ]
#  [2.         0.25558748 0.43900795]
#  [2.         0.08000382 0.83010555]]

# %%
seedss = [18998, 15596, 12877, 8795, 9412, 9920, 11842,4, 15148,5774,3210,15399,6144,6085,11049,14122,7754,12448,3865,13403,477]

#del menos f al 2.5 mayor
seedss = [18998, 15596, 12877, 8795, 9412, 9920, 11842,4, 15148,5774,3210,15399,6144,6085,11049,14122,7754,12448,3865,13403,477]

for i in seeds:
    seed = np.random.seed(i)
    vertices = random_vertices_by_fiber([0,1,2], 2, 10)

    hull = ConvexHull(vertices)

    print(vertices)

    x = vertices[:,0]
    y = vertices[:,1]
    z = vertices[:,2]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c='blue', s=10, label='Puntos Input', alpha=0.5)
    #ax.plot(x, y, z, c='blue', alpha=0.7, label='Línea de Conexión')

    envoltura = Poly3DCollection(vertices[hull.simplices])
    envoltura.set_facecolor('cyan')
    envoltura.set_alpha(0.3)
    envoltura.set_edgecolor('blue')
    envoltura.set_linewidth(0.5)

    ax.add_collection3d(envoltura)

    plt.show()
# Out:
# [[0.         0.42952983 0.81316496]
#  [0.         0.77527515 0.58997708]
#  [0.         0.2471078  0.90860791]
#  [0.         0.74904735 0.56991393]
#  [0.         0.55378691 0.74349415]
#  [0.         0.62866027 0.99010376]
#  [0.         0.87782631 0.11598061]
#  [0.         0.68068832 0.79589575]
#  [0.         0.4248034  0.51933697]
#  [0.         0.56123841 0.49555462]
#  [1.         0.22798754 0.03057636]
#  [1.         0.39783404 0.07617288]
#  [1.         0.34335381 0.95088272]
#  [1.         0.99682508 0.14467119]
#  [1.         0.52033157 0.9397101 ]
#  [1.         0.95540243 0.86896464]
#  [1.         0.87710572 0.71393992]
#  [1.         0.86716959 0.15957725]
#  [1.         0.66129844 0.43245493]
#  [1.         0.08005788 0.17621606]
#  [2.         0.37816461 0.28078987]
#  [2.         0.60563248 0.05707329]
#  [2.         0.80251642 0.18969067]
#  [2.         0.92466178 0.66306734]
#  [2.         0.15107978 0.79653669]
#  [2.         0.79242546 0.91309191]
#  [2.         0.71314879 0.94452365]
#  [2.         0.0799974  0.34030045]
#  [2.         0.9991439  0.73471593]
#  [2.         0.5284364  0.22709591]]
# [[0.         0.77326925 0.57763015]
#  [0.         0.83760802 0.60035907]
#  [0.         0.30057401 0.60685448]
#  [0.         0.92410269 0.61052066]
#  [0.         0.51992927 0.58250509]
#  [0.         0.31372596 0.83855441]
#  [0.         0.18555182 0.53105619]
#  [0.         0.05860578 0.78491644]
#  [0.         0.28413968 0.91719556]
#  [0.         0.55168591 0.37940877]
#  [1.         0.37030061 0.85951065]
#  [1.         0.0739258  0.28854666]
#  [1.         0.07606402 0.61318147]
#  [1.         0.94640472 0.57644544]
#  [1.         0.19374699 0.16049924]
#  [1.         0.1132395  0.70753524]
#  [1.         0.28991456 0.17656782]
#  [1.         0.94405247 0.25168681]
#  [1.         0.9430529  0.7402563 ]
#  [1.         0.29634646 0.00228732]
#  [2.         0.26854172 0.57337405]
#  [2.         0.57056842 0.54729188]
#  [2.         0.1099036  0.63168038]
#  [2.         0.49165065 0.11427045]
#  [2.         0.29024799 0.4383414 ]
#  [2.         0.73352676 0.78877546]
#  [2.         0.01295343 0.57354278]
#  [2.         0.81943204 0.61469719]
#  [2.         0.0248189  0.50907833]
#  [2.         0.88417884 0.82893654]]
# [[0.00000000e+00 2.54652728e-01 1.73172756e-01]
#  [0.00000000e+00 3.67181938e-01 1.35967990e-01]
#  [0.00000000e+00 5.17839466e-01 1.49420740e-01]
#  [0.00000000e+00 1.14544999e-01 8.65744067e-02]
#  [0.00000000e+00 2.92229706e-01 1.77296481e-01]
#  [0.00000000e+00 6.60725416e-01 3.37410569e-01]
#  [0.00000000e+00 3.36161362e-01 4.29462348e-01]
#  [0.00000000e+00 9.14337363e-01 5.50332047e-01]
#  [0.00000000e+00 2.02878224e-01 4.96043820e-01]
#  [0.00000000e+00 2.36904947e-01 6.03387924e-01]
#  [1.00000000e+00 1.60604163e-03 5.32780932e-01]
#  [1.00000000e+00 5.45902453e-01 3.76936145e-01]
#  [1.00000000e+00 8.72519945e-01 8.95285642e-01]
#  [1.00000000e+00 8.78521818e-01 4.11789009e-01]
#  [1.00000000e+00 5.59924961e-02 4.17689600e-01]
#  [1.00000000e+00 6.12278481e-01 3.87662691e-01]
#  [1.00000000e+00 3.57125029e-03 4.96177553e-01]
#  [1.00000000e+00 7.82556029e-01 6.10425949e-01]
#  [1.00000000e+00 6.31614122e-01 3.95788144e-01]
#  [1.00000000e+00 7.59047616e-01 2.10630963e-01]
#  [2.00000000e+00 4.68793736e-01 8.07377832e-02]
#  [2.00000000e+00 6.05329833e-01 8.59052813e-02]
#  [2.00000000e+00 5.80376933e-01 3.46201692e-01]
#  [2.00000000e+00 8.02195764e-01 8.98216908e-01]
#  [2.00000000e+00 6.39364102e-01 2.87642527e-01]
#  [2.00000000e+00 5.66445042e-01 2.15285314e-01]
#  [2.00000000e+00 6.24111439e-01 7.89413189e-01]
#  [2.00000000e+00 6.98131517e-01 5.27109854e-01]
#  [2.00000000e+00 5.58380414e-01 6.68992618e-01]
#  [2.00000000e+00 6.08235234e-01 4.14692548e-01]]
# [[0.         0.08482016 0.57718741]
#  [0.         0.9049527  0.90262225]
#  [0.         0.10091194 0.15005473]
#  [0.         0.68096257 0.93834487]
#  [0.         0.85563296 0.16323702]
#  [0.         0.35314192 0.89420428]
#  [0.         0.54136601 0.55366649]
#  [0.         0.9578166  0.7987959 ]
#  [0.         0.68891183 0.44837514]
#  [0.         0.31716992 0.84912247]
#  [1.         0.29690867 0.32088587]
#  [1.         0.36807854 0.08402662]
#  [1.         0.40545343 0.07391404]
#  [1.         0.1919406  0.55148922]
#  [1.         0.31876932 0.39103044]
#  [1.         0.00875419 0.91548033]
#  [1.         0.58525358 0.72622418]
#  [1.         0.86020934 0.92792621]
#  [1.         0.73475639 0.13772678]
#  [1.         0.63505878 0.98436106]
#  [2.         0.3491834  0.65538266]
#  [2.         0.71034989 0.04932604]
#  [2.         0.20849508 0.40412311]
#  [2.         0.11388592 0.23737296]
#  [2.         0.56976705 0.12099601]
#  [2.         0.86322604 0.01491375]
#  [2.         0.79505477 0.53766445]
#  [2.         0.29746127 0.84595351]
#  [2.         0.54184906 0.30791153]
#  [2.         0.26574272 0.29539776]]
# [[0.         0.00875573 0.29874557]
#  [0.         0.05641407 0.48268692]
#  [0.         0.28184322 0.794274  ]
#  [0.         0.29180757 0.7347585 ]
#  [0.         0.22156677 0.7164294 ]
#  [0.         0.05173477 0.49551781]
#  [0.         0.6625002  0.74884771]
#  [0.         0.70220684 0.25435969]
#  [0.         0.54762501 0.72802443]
#  [0.         0.79250279 0.22616673]
#  [1.         0.04926547 0.11584708]
#  [1.         0.9951388  0.79756743]
#  [1.         0.57700001 0.18489245]
#  [1.         0.12829891 0.74101994]
#  [1.         0.26291438 0.6475314 ]
#  [1.         0.36231972 0.34040627]
#  [1.         0.30513079 0.07907198]
#  [1.         0.00650969 0.08624177]
#  [1.         0.2613288  0.17291938]
#  [1.         0.74550749 0.19025432]
#  [2.         0.27940303 0.45820277]
#  [2.         0.39290228 0.90237234]
#  [2.         0.95565683 0.43838154]
#  [2.         0.94216292 0.30748088]
#  [2.         0.86424441 0.65935672]
#  [2.         0.24372409 0.07989746]
#  [2.         0.58157929 0.98481722]
#  [2.         0.75879289 0.14801999]
#  [2.         0.63582293 0.16216941]
#  [2.         0.488785   0.58568464]]
# [[0.         0.02586125 0.52115023]
#  [0.         0.95896677 0.20084518]
#  [0.         0.68776187 0.92728843]
#  [0.         0.3673128  0.84997458]
#  [0.         0.12269898 0.31439832]
#  [0.         0.35294414 0.7561953 ]
#  [0.         0.40066524 0.24513609]
#  [0.         0.58221092 0.00241572]
#  [0.         0.80304896 0.57299164]
#  [0.         0.88214127 0.09327788]
#  [1.         0.36825938 0.37243118]
#  [1.         0.48750641 0.58121839]
#  [1.         0.4095723  0.34789037]
#  [1.         0.55538195 0.64993855]
#  [1.         0.59372064 0.80977813]
#  [1.         0.36302015 0.96748327]
#  [1.         0.83380503 0.00997511]
#  [1.         0.17924285 0.27963566]
#  [1.         0.99731406 0.15904646]
#  [1.         0.71259653 0.37567467]
#  [2.         0.36909382 0.78032268]
#  [2.         0.52282275 0.49619448]
#  [2.         0.11225944 0.27063121]
#  [2.         0.59103019 0.44008261]
#  [2.         0.5357696  0.30350906]
#  [2.         0.17256322 0.30959765]
#  [2.         0.69555583 0.22788152]
#  [2.         0.87784812 0.20472804]
#  [2.         0.54842023 0.41544308]
#  [2.         0.97941334 0.55977327]]
# [[0.         0.58585809 0.62343154]
#  [0.         0.34965945 0.47745566]
#  [0.         0.81718172 0.77255311]
#  [0.         0.24436355 0.38744932]
#  [0.         0.68421916 0.69901165]
#  [0.         0.69881232 0.41007985]
#  [0.         0.32770875 0.03384754]
#  [0.         0.72620142 0.50805211]
#  [0.         0.92396585 0.43854411]
#  [0.         0.69157719 0.31024349]
#  [1.         0.56232263 0.06597465]
#  [1.         0.20111905 0.51636098]
#  [1.         0.37551645 0.67050732]
#  [1.         0.19922245 0.17858819]
#  [1.         0.98066578 0.54742396]
#  [1.         0.80920039 0.69337407]
#  [1.         0.38794761 0.49174167]
#  [1.         0.66623982 0.51583787]
#  [1.         0.36268082 0.17629652]
#  [1.         0.93592905 0.92166126]
#  [2.         0.68019286 0.54770076]
#  [2.         0.92860103 0.89606543]
#  [2.         0.2123415  0.06829669]
#  [2.         0.32581295 0.41339504]
#  [2.         0.96707627 0.69938864]
#  [2.         0.00475355 0.98045926]
#  [2.         0.15238904 0.45758974]
#  [2.         0.55192558 0.35898316]
#  [2.         0.98851107 0.98319139]
#  [2.         0.22072871 0.86488016]]
# [[0.         0.95543975 0.4470709 ]
#  [0.         0.89494061 0.869291  ]
#  [0.         0.48543238 0.80347368]
#  [0.         0.10519524 0.79568904]
#  [0.         0.9379793  0.03416829]
#  [0.         0.72892749 0.1100535 ]
#  [0.         0.5444354  0.20566125]
#  [0.         0.51957894 0.35536247]
#  [0.         0.10990077 0.49715343]
#  [0.         0.70852423 0.24149979]
#  [1.         0.15136546 0.47757788]
#  [1.         0.68429402 0.16683398]
#  [1.         0.3166149  0.35651084]
#  [1.         0.54118897 0.30748   ]
#  [1.         0.4619165  0.24242057]
#  [1.         0.90842753 0.77051989]
#  [1.         0.39531392 0.22696629]
#  [1.         0.49784555 0.6978833 ]
#  [1.         0.10630164 0.69616522]
#  [1.         0.1663495  0.4387363 ]
#  [2.         0.20979876 0.95163606]
#  [2.         0.70729911 0.4437479 ]
#  [2.         0.30736933 0.32671797]
#  [2.         0.95182913 0.47713391]
#  [2.         0.49240941 0.08864653]
#  [2.         0.96729031 0.5108824 ]
#  [2.         0.72366861 0.83871137]
#  [2.         0.03098291 0.34830044]
#  [2.         0.28421916 0.27791461]
#  [2.         0.66028884 0.39496383]]
# [[0.         0.02151438 0.57736926]
#  [0.         0.99713067 0.98341528]
#  [0.         0.95797162 0.06009384]
#  [0.         0.3633497  0.92566958]
#  [0.         0.82963888 0.86134648]
#  [0.         0.35500373 0.27203852]
#  [0.         0.10284408 0.87423524]
#  [0.         0.6030561  0.23752438]
#  [0.         0.06520852 0.32081546]
#  [0.         0.05581486 0.4495711 ]
#  [1.         0.52911538 0.1920056 ]
#  [1.         0.6473016  0.18829031]
#  [1.         0.49808732 0.15085068]
#  [1.         0.20422581 0.25542795]
#  [1.         0.6122392  0.03045917]
#  [1.         0.78821958 0.57309468]
#  [1.         0.51286445 0.47129086]
#  [1.         0.93095199 0.76757069]
#  [1.         0.50267614 0.88681121]
#  [1.         0.24729043 0.46577208]
#  [2.         0.02043707 0.12008509]
#  [2.         0.7217628  0.86218301]
#  [2.         0.5206023  0.49662237]
#  [2.         0.40747578 0.53838594]
#  [2.         0.18343004 0.15224327]
#  [2.         0.33583344 0.18185646]
#  [2.         0.81478738 0.14524426]
#  [2.         0.68488332 0.16104212]
#  [2.         0.75156508 0.170599  ]
#  [2.         0.8684301  0.92776217]]
# [[0.         0.38492541 0.98279983]
#  [0.         0.7525498  0.95698608]
#  [0.         0.48957568 0.06359224]
#  [0.         0.06607759 0.82856383]
#  [0.         0.85779503 0.57244201]
#  [0.         0.39219375 0.73278113]
#  [0.         0.19377543 0.53300436]
#  [0.         0.92765511 0.4465151 ]
#  [0.         0.50458381 0.89969619]
#  [0.         0.23199468 0.66863259]
#  [1.         0.25692004 0.53746384]
#  [1.         0.29475577 0.18260746]
#  [1.         0.24364159 0.5777635 ]
#  [1.         0.25558748 0.43900795]
#  [1.         0.08000382 0.83010555]
#  [1.         0.7931749  0.4956275 ]
#  [1.         0.44942782 0.18312801]
#  [1.         0.416808   0.38925331]
#  [1.         0.96987186 0.74779392]
#  [1.         0.91378528 0.12920997]
#  [2.         0.81841953 0.92282461]
#  [2.         0.57671418 0.40339212]
#  [2.         0.11444079 0.89096241]
#  [2.         0.62821825 0.1893027 ]
#  [2.         0.94107023 0.99443041]
#  [2.         0.36118854 0.18598856]
#  [2.         0.36027519 0.09013402]
#  [2.         0.43113869 0.30483134]
#  [2.         0.90628291 0.11238564]
#  [2.         0.54977343 0.3813838 ]]
