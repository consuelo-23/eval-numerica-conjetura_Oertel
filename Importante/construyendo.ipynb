# %%
from convex_hull import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
import matplotlib.pyplot as plt
from new_oertel import area_total
from new_oertel import area_por_slice

vertices = random_vertices_by_fiber([0,1,2], 2, 5)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], 
        c='blue', s=150, label='Puntos Input', alpha=0.5)
plt.show()

candidatos, ordenados = obtener_candidatos(vertices)



import numpy as np
for z in [0,1,2]:
     grupo = ordenados[np.isclose(ordenados[:, 0], z)]

     grupo = grupo[:,1:]
     area = area_por_slice(grupo, z)
     print(area)

Area_ = area_total(vertices)
print(Area_)
print(candidatos)
#-------ahora a obtener el radio de oertel--------
# Out:
# slice: 0
# [[0.         0.76732153 0.3868379 ]
#  [0.         0.3310258  0.54775892]
#  [0.         0.01360006 0.04316692]
#  [0.         0.01895658 0.65652258]
#  [0.         0.27683626 0.21904597]]
# [[0.         0.01360006 0.04316692]
#  [0.         0.76732153 0.3868379 ]
#  [0.         0.3310258  0.54775892]
#  [0.         0.01895658 0.65652258]]
# slice: 1
# [[1.         0.67823065 0.70506167]
#  [1.         0.74435571 0.61024107]
#  [1.         0.88068007 0.31884621]
#  [1.         0.7584445  0.39182461]
#  [1.         0.11287842 0.35162328]]
# [[1.         0.67823065 0.70506167]
#  [1.         0.13244692 0.80019019]
#  [1.         0.04457487 0.60180598]
#  [1.         0.03569581 0.55320098]
#  [1.         0.03301755 0.24652316]
#  [1.         0.28658283 0.09690406]
#  [1.         0.48631595 0.07222552]
#  [1.         0.86317669 0.24406101]
#  [1.         0.88068007 0.31884621]
#  [1.         0.74435571 0.61024107]]
# slice: 2
# [[2.         0.07019316 0.54708938]
# ...
