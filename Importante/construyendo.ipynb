# %%
from convex_hull import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
import matplotlib.pyplot as plt

vertices = random_vertices_by_fiber([0,1,2], 2, 5)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], 
        c='blue', s=150, label='Puntos Input', alpha=0.5)
plt.show()

candidatos = obtener_candidatos(vertices,)

#-------ahora a obtener el radio de oertel--------
# Out:
# slice: 0
# [[0.         0.79519021 0.16217278]
#  [0.         0.90561331 0.18401861]
#  [0.         0.05509224 0.36879049]
#  [0.         0.26216709 0.81862837]
#  [0.         0.77155044 0.6124314 ]]
# [[0.         0.26216709 0.81862837]
#  [0.         0.05509224 0.36879049]
#  [0.         0.79519021 0.16217278]
#  [0.         0.90561331 0.18401861]
#  [0.         0.77155044 0.6124314 ]]
# slice: 1
# [[1.         0.23277266 0.75784844]
#  [1.         0.10278592 0.39053468]
#  [1.         0.33174583 0.27169683]
#  [1.         0.53855243 0.94899364]
#  [1.         0.28958235 0.49423677]]
# [[1.         0.83955818 0.58035138]
#  [1.         0.77252674 0.79455777]
#  [1.         0.53855243 0.94899364]
#  [1.         0.23277266 0.75784844]
#  [1.         0.10278592 0.39053468]
#  [1.         0.08091928 0.2670205 ]
#  [1.         0.18780255 0.20164593]
#  [1.         0.55785153 0.09833708]
#  [1.         0.61306308 0.10926   ]]
# slice: 2
# [[2.         0.32051285 0.03450138]
#  [2.         0.77350305 0.97668414]
#  [2.         0.46159336 0.53755778]
#  [2.         0.10674631 0.16525051]
#  [2.         0.2328565  0.24308428]]
# [[2.         0.10674631 0.16525052]
#  [2.         0.32051285 0.03450138]
#  [2.         0.77350305 0.97668414]]
