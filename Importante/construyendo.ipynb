# %%
from convex_hull import random_vertices_by_fiber
from get_cpoints import obtener_candidatos
import matplotlib.pyplot as plt
from new_oertel import area_total
from new_oertel import area_por_slice

vertices = random_vertices_by_fiber([0,1,2], 2, 5)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], 
        c='blue', s=150, label='Puntos Input', alpha=0.5)
plt.show()

candidatos = obtener_candidatos(vertices)



import numpy as np
for z in [0,1,2]:
     grupo = vertices[np.isclose(vertices[:, 0], z)]

     grupo = grupo[:,1:]
     area = area_por_slice(grupo, z)
     print(area)

Area_ = area_total(vertices)
print(Area_)
print(candidatos)
#-------ahora a obtener el radio de oertel--------
# Out:
# slice: 0
# [[0.         0.41714659 0.7650334 ]
#  [0.         0.38770592 0.10294632]
#  [0.         0.26921836 0.09565944]
#  [0.         0.81080902 0.2996131 ]
#  [0.         0.82019961 0.41387378]]
# [[0.         0.41714659 0.7650334 ]
#  [0.         0.26921836 0.09565944]
#  [0.         0.38770592 0.10294632]
#  [0.         0.81080902 0.2996131 ]
#  [0.         0.82019961 0.41387378]]
# slice: 1
# [[1.         0.23400527 0.97838762]
#  [1.         0.78620159 0.95199325]
#  [1.         0.77792535 0.57949479]
#  [1.         0.94528978 0.28949325]
#  [1.         0.24196196 0.24489783]]
# [[1.         0.78620159 0.95199325]
#  [1.         0.23400527 0.97838762]
#  [1.         0.24196196 0.24489783]
#  [1.         0.29518683 0.10002802]
#  [1.         0.35443061 0.10367146]
#  [1.         0.66938449 0.19779853]
#  [1.         0.94528978 0.28949325]]
# slice: 2
# [[2.         0.70051697 0.34610778]
#  [2.         0.91382218 0.36156423]
#  [2.         0.3211553  0.10439659]
#  [2.         0.95106307 0.29265074]
#  [2.         0.70135486 0.77375866]]
# [[2.         0.3211553  0.10439659]
#  [2.         0.95106307 0.29265074]
#  [2.         0.70135486 0.77375866]]
# 0.15173617011854568
# -0.406563262792075
# 0.07116786222257612
# -0.1836592304509532
# [array([0.        , 0.52111513, 0.38869027]), array([1.        , 0.54294939, 0.5553762 ]), array([2.        , 0.65785774, 0.39026866]), array([1.        , 0.58948644, 0.38947947]), [array([1.        , 0.54294939, 0.5553762 ]), array([1.        , 0.54389913, 0.55199055]), array([1.        , 0.54484886, 0.5486049 ]), array([1.        , 0.5457986 , 0.54521926]), array([1.        , 0.54674833, 0.54183361]), array([1.        , 0.54769807, 0.53844796]), array([1.        , 0.54864781, 0.53506231]), array([1.        , 0.54959754, 0.53167667]), array([1.        , 0.55054728, 0.52829102]), array([1.        , 0.55149701, 0.52490537]), array([1.        , 0.55244675, 0.52151972]), array([1.        , 0.55339648, 0.51813408]), array([1.        , 0.55434622, 0.51474843]), array([1.        , 0.55529596, 0.51136278]), array([1.        , 0.55624569, 0.50797713]), array([1.        , 0.55719543, 0.50459149]), array([1.        , 0.55814516, 0.50120584]), array([1.        , 0.5590949 , 0.49782019]), array([1.        , 0.56004463, 0.49443454]), array([1.        , 0.56099437, 0.4910489 ]), array([1.        , 0.5619441 , 0.48766325]), array([1.        , 0.56289384, 0.4842776 ]), array([1.        , 0.56384358, 0.48089195]), array([1.        , 0.56479331, 0.47750631]), array([1.        , 0.56574305, 0.47412066]), array([1.        , 0.56669278, 0.47073501]), array([1.        , 0.56764252, 0.46734936]), array([1.        , 0.56859225, 0.46396371]), array([1.        , 0.56954199, 0.46057807]), array([1.        , 0.57049173, 0.45719242]), array([1.        , 0.57144146, 0.45380677]), array([1.        , 0.5723912 , 0.45042112]), array([1.        , 0.57334093, 0.44703548]), array([1.        , 0.57429067, 0.44364983]), array([1.        , 0.5752404 , 0.44026418]), array([1.        , 0.57619014, 0.43687853]), array([1.        , 0.57713987, 0.43349289]), array([1.        , 0.57808961, 0.43010724]), array([1.        , 0.57903935, 0.42672159]), array([1.        , 0.57998908, 0.42333594]), array([1.        , 0.58093882, 0.4199503 ]), array([1.        , 0.58188855, 0.41656465]), array([1.        , 0.58283829, 0.413179  ]), array([1.        , 0.58378802, 0.40979335]), array([1.        , 0.58473776, 0.40640771]), array([1.        , 0.58568749, 0.40302206]), array([1.        , 0.58663723, 0.39963641]), array([1.        , 0.58758697, 0.39625076]), array([1.        , 0.5885367 , 0.39286512]), array([1.        , 0.58948644, 0.38947947])]]
